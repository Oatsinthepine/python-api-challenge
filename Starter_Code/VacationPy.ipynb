# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0  edinburgh of the seven seas -37.0676  -12.3116     15.27
# 1        1                         argo  37.6333   22.7333     24.88
# 2        2                    tocopilla -22.0920  -70.1979     17.99
# 3        3                blackmans bay -43.0167  147.3167      6.96
# 4        4                      ushuaia -54.8000  -68.3000     -3.19
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        88         100       14.40      SH  1719713912
# 1        45           0        2.48      GR  1719713913
# 2        62           1        2.46      CL  1719713914
# 3        90         100        0.45      AU  1719713916
# 4        74           0        2.06      AR  1719713917

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map_plot = city_data_df.hvplot.points('Lng', 'Lat', geo= True, tiles = 'OSM', frame_width = 700, \
                                          frame_height = 500, size = 'Humidity', scale=0.9, color= 'City')
# Display the map
city_map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
selected_city_data_df = city_data_df.loc[(city_data_df['Max Temp']> 21) & (city_data_df['Max Temp'] < 27) & \
                                        (city_data_df['Wind Speed'] < 4.5) & (city_data_df['Cloudiness'] == 0)]
selected_city_data_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 1          1             argo  37.6333   22.7333     24.88        45
# 96        96  remire-montjoly   4.9167  -52.2667     25.02       100
# 107      107         hamilton  39.1834  -84.5333     23.75        95
# 190      190           at taj  24.2049   23.2857     25.97        28
# 211      211       vila velha -20.3297  -40.2925     24.97        65
# 213      213           broome  42.2506  -75.8330     23.17        91
# 286      286            ha'il  27.5219   41.6907     25.01        20
# 292      292           zalari  53.5584  102.5065     26.93        44
# 306      306          nambour -26.6333  152.9500     24.92        81
# 327      327         itaituba  -4.2761  -55.9836     26.09        94
# 381      381        qarqaraly  49.4058   75.4742     21.81        47
# 383      383         belmonte -15.8631  -38.8828     22.77        79
# 407      407          corning  42.1428  -77.0547     23.76        89
# ...

# %%
# Drop any rows with null values
selected_city_data_df = selected_city_data_df.dropna()

# Display sample data
selected_city_data_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 1          1             argo  37.6333   22.7333     24.88        45
# 96        96  remire-montjoly   4.9167  -52.2667     25.02       100
# 107      107         hamilton  39.1834  -84.5333     23.75        95
# 190      190           at taj  24.2049   23.2857     25.97        28
# 211      211       vila velha -20.3297  -40.2925     24.97        65
# 213      213           broome  42.2506  -75.8330     23.17        91
# 286      286            ha'il  27.5219   41.6907     25.01        20
# 292      292           zalari  53.5584  102.5065     26.93        44
# 306      306          nambour -26.6333  152.9500     24.92        81
# 327      327         itaituba  -4.2761  -55.9836     26.09        94
# 381      381        qarqaraly  49.4058   75.4742     21.81        47
# 383      383         belmonte -15.8631  -38.8828     22.77        79
# 407      407          corning  42.1428  -77.0547     23.76        89
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
city_data_df_copy = selected_city_data_df.copy()
city_data_df_copy = city_data_df_copy[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
city_data_df_copy['Hotel Name'] = ""

# Display sample data
city_data_df_copy
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 1               argo      GR  37.6333   22.7333        45
# 96   remire-montjoly      GF   4.9167  -52.2667       100
# 107         hamilton      US  39.1834  -84.5333        95
# 190           at taj      LY  24.2049   23.2857        28
# 211       vila velha      BR -20.3297  -40.2925        65
# 213           broome      US  42.2506  -75.8330        91
# 286            ha'il      SA  27.5219   41.6907        20
# 292           zalari      RU  53.5584  102.5065        44
# 306          nambour      AU -26.6333  152.9500        81
# 327         itaituba      BR  -4.2761  -55.9836        94
# 381        qarqaraly      KZ  49.4058   75.4742        47
# 383         belmonte      BR -15.8631  -38.8828        79
# 407          corning      US  42.1428  -77.0547        89
# 432          matoury      GF   4.8483  -52.3317       100
# 438         old town      CZ  50.0870   14.4202        76
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 # YOUR CODE HERE
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 3
}

# Print a message to follow up the hotel search
print("Starting hotel search...")

# Iterate through the DataFrame
for index, row in city_data_df_copy.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}" 
    params["bias"] = f"proximity:{longitude},{latitude}" 

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params) 

    # Convert the API response to JSON format
    name_address = name_address.json()  

    # Grab the first hotel from the results and store the name in the DataFrame
    try:
        city_data_df_copy.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        city_data_df_copy.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{city_data_df_copy.loc[index, 'City']} - nearest hotel: {city_data_df_copy.loc[index, 'Hotel Name']}")

# Display sample data
city_data_df_copy
# Out:
# Starting hotel search...
# argo - nearest hotel: Apollon Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# hamilton - nearest hotel: North Vista Manor
# at taj - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# broome - nearest hotel: No hotel found
# ha'il - nearest hotel: فندق كلاسيك
# zalari - nearest hotel: No hotel found
# nambour - nearest hotel: Amytis Gardens
# itaituba - nearest hotel: TG Hotel
# qarqaraly - nearest hotel: Каркаралинск
# belmonte - nearest hotel: No hotel found
# corning - nearest hotel: Radisson Hotel Corning
# matoury - nearest hotel: La Marmotte
# old town - nearest hotel: Terasa U Prince
# heihe - nearest hotel: Санкт-Петербург
# pirot - nearest hotel: Гали апартамани
# sidi akkacha - nearest hotel: Hôtel des Arts
# sfax - nearest hotel: دار بية
# kone - nearest hotel: Pacifik Appartels
# marsala - nearest hotel: Stella d'Italia
# guercif - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#save and export dataframe:
city_data_df_copy.to_csv('hotel_city_outfile.csv', encoding= 'utf-8', index = True, header = True)

# %%
# %%capture --no-display

# Configure the map plot
 
hotel_map = city_data_df_copy.hvplot.points('Lng', 'Lat', geo = True, tiles = 'OSM', frame_width = 700, \
                                          frame_height = 500, size = 'Humidity', scale=1.2, color= 'City', \
                                          hover_cols = 'Hotel Name')


# Display the map
 
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
